# %% [markdown]
# Here, we fully reproduce our results in the paper for the GMIC architecture. Set `dnn_architecture = 'dmv'` for the DMV architecture.

# %%
import gin
import matplotlib.pyplot as plt
from code import probabilistic_inference, perturbation_study_analysis, annotation_study_analysis

dnn_architecture = 'gmic'

# %% [markdown]
# ## Probabilistic inference

# %%
# # Generate posterior samples for radiologists
# gin.parse_config_file('cfg/probabilistic_inference/radiologists.gin')
# probabilistic_inference.main()
# # Generate posterior samples for DNNs trained with unperturbed data
# gin.parse_config_file(f'cfg/probabilistic_inference/dnns/{dnn_architecture}/unperturbed.gin')
# probabilistic_inference.main()
# # Generate posterior samples for DNNs trained with low-pass filtered data
# gin.parse_config_file(f'cfg/probabilistic_inference/dnns/{dnn_architecture}/filtered.gin')
# probabilistic_inference.main()
# Out:
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_7e47ebdb86ff10b264d17b0a615ecd9c NOW.
# WARNING:pystan:Automatic Differentiation Variational Inference (ADVI) is an EXPERIMENTAL ALGORITHM.
# WARNING:pystan:ADVI samples may be found on the filesystem in the file `/var/folders/xx/09q83t_s6vs4j7clwr79bl380000gn/T/tmpmigqmmfy/output.csv`
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_bd0de2bb433b593580a70a501aae9f34 NOW.
# WARNING:pystan:Automatic Differentiation Variational Inference (ADVI) is an EXPERIMENTAL ALGORITHM.
# WARNING:pystan:ADVI samples may be found on the filesystem in the file `/var/folders/xx/09q83t_s6vs4j7clwr79bl380000gn/T/tmp78omkhma/output.csv`
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_bd0de2bb433b593580a70a501aae9f34 NOW.
# WARNING:pystan:Automatic Differentiation Variational Inference (ADVI) is an EXPERIMENTAL ALGORITHM.
# ...

# %% [markdown]
# ## Perturbation study analysis (microcalcifications)

# %%
gin.parse_config_file(f'cfg/perturbation_study_analysis/{dnn_architecture}/microcalcifications.gin')
perturbation_study_analysis.main()
# Out:
# INFO:matplotlib.mathtext:Substituting symbol D from STIXNonUnicode
# INFO:matplotlib.mathtext:Substituting symbol D from STIXNonUnicode
# INFO:matplotlib.mathtext:Substituting symbol D from STIXNonUnicode

# %% [markdown]
# ## Perturbation study analysis (soft tissue lesions)

# %%
gin.parse_config_file(f'cfg/perturbation_study_analysis/{dnn_architecture}/soft_tissue_lesions.gin')
perturbation_study_analysis.main()
# Out:
# INFO:matplotlib.mathtext:Substituting symbol D from STIXNonUnicode
# INFO:matplotlib.mathtext:Substituting symbol D from STIXNonUnicode
# INFO:matplotlib.mathtext:Substituting symbol D from STIXNonUnicode

# %% [markdown]
# ## Annotation study analysis (left: microcalcifications, right: soft tissue lesions)

# %%
gin.parse_config_file(f'cfg/annotation_study_analysis/{dnn_architecture}.gin')
annotation_study_analysis.main()
